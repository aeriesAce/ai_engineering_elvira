# %%
from dotenv import load_dotenv
from google import genai
import os

load_dotenv()
client = genai.Client(api_key=os.getenv("GEMENI_API_KEY"))

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI learns patterns from data to make intelligent decisions or predictions.

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="""You are a helpful assistant. I need you to create a JSON object representing a library. 
    The library's name should be 'Coolu Libraru' and have the fields name and books that contains a list of book. 
    Each book should have a 'title', 'author', and 'year' field. Make sure the output is a single, valid JSON object. Give me 10 books. 
    Remove ```json and ``` """,
)

response.text
# Out:
# '{\n  "name": "Coolu Libraru",\n  "books": [\n    {\n      "title": "The Silent Melody",\n      "author": "Alice Wonderland",\n      "year": 2018\n    },\n    {\n      "title": "Whispers of the Old Forest",\n      "author": "Robert Green",\n      "year": 1995\n    },\n    {\n      "title": "Stars Above Us",\n      "author": "Clara Nova",\n      "year": 2022\n    },\n    {\n      "title": "The Last Cartographer",\n      "author": "Jonathan Swift",\n      "year": 1987\n    },\n    {\n      "title": "Echoes in the Canyon",\n      "author": "Sarah Fields",\n      "year": 2001\n    },\n    {\n      "title": "Beyond the Horizon",\n      "author": "Marcus Aurelius",\n      "year": 1973\n    },\n    {\n      "title": "The Clockwork Heart",\n      "author": "Victoria Steampunk",\n      "year": 2010\n    },\n    {\n      "title": "Shadows of Yesterday",\n      "author": "David Night",\n      "year": 1965\n    },\n    {\n      "title": "The Golden Compass",\n      "author": "Philip Pullman",\n      "year": 1995\n    },\n    {\n      "title": "Aetherial Dreams",\n      "author": "Evelyn Myst",\n      "year": 2015\n    }\n  ]\n}'

# %%
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(response)
#
# NameError: name 'response' is not defined

# %%
print(response.text)
# Out:
# {
#   "name": "Coolu Libraru",
#   "books": [
#     {
#       "title": "The Silent Melody",
#       "author": "Alice Wonderland",
#       "year": 2018
#     },
#     {
#       "title": "Whispers of the Old Forest",
#       "author": "Robert Green",
#       "year": 1995
#     },
#     {
#       "title": "Stars Above Us",
#       "author": "Clara Nova",
#       "year": 2022
#     },
#     {
#       "title": "The Last Cartographer",
#       "author": "Jonathan Swift",
#       "year": 1987
#     },
#     {
#       "title": "Echoes in the Canyon",
#       "author": "Sarah Fields",
#       "year": 2001
#     },
#     {
#       "title": "Beyond the Horizon",
#       "author": "Marcus Aurelius",
#       "year": 1973
#     },
#     {
#       "title": "The Clockwork Heart",
#       "author": "Victoria Steampunk",
#       "year": 2010
#     },
#     {
#       "title": "Shadows of Yesterday",
#       "author": "David Night",
#       "year": 1965
#     },
#     {
#       "title": "The Golden Compass",
#       "author": "Philip Pullman",
#       "year": 1995
#     },
#     {
#       "title": "Aetherial Dreams",
#       "author": "Evelyn Myst",
#       "year": 2015
#     }
#   ]
# }

# %%
from pydantic import BaseModel, Field
from typing import List
from datetime import datetime

class Book(BaseModel):
    title: str
    author: str
    year: int = Field(gt = 1000, lt = datetime.now().year)

class Library(BaseModel):
    name: str
    books: List[Book]

library = Library.model_validate_json(response.text)
library
# Out:
# Library(name='Coolu Libraru', books=[Book(title='The Silent Melody', author='Alice Wonderland', year=2018), Book(title='Whispers of the Old Forest', author='Robert Green', year=1995), Book(title='Stars Above Us', author='Clara Nova', year=2022), Book(title='The Last Cartographer', author='Jonathan Swift', year=1987), Book(title='Echoes in the Canyon', author='Sarah Fields', year=2001), Book(title='Beyond the Horizon', author='Marcus Aurelius', year=1973), Book(title='The Clockwork Heart', author='Victoria Steampunk', year=2010), Book(title='Shadows of Yesterday', author='David Night', year=1965), Book(title='The Golden Compass', author='Philip Pullman', year=1995), Book(title='Aetherial Dreams', author='Evelyn Myst', year=2015)])

# %%
library.__dict__
# Out:
# {'name': 'Coolu Libraru',
#  'books': [Book(title='The Silent Melody', author='Alice Wonderland', year=2018),
#   Book(title='Whispers of the Old Forest', author='Robert Green', year=1995),
#   Book(title='Stars Above Us', author='Clara Nova', year=2022),
#   Book(title='The Last Cartographer', author='Jonathan Swift', year=1987),
#   Book(title='Echoes in the Canyon', author='Sarah Fields', year=2001),
#   Book(title='Beyond the Horizon', author='Marcus Aurelius', year=1973),
#   Book(title='The Clockwork Heart', author='Victoria Steampunk', year=2010),
#   Book(title='Shadows of Yesterday', author='David Night', year=1965),
#   Book(title='The Golden Compass', author='Philip Pullman', year=1995),
#   Book(title='Aetherial Dreams', author='Evelyn Myst', year=2015)]}

# %%
type(library)
# Out:
# __main__.Library

# %%
isinstance(library, BaseModel)
# Out:
# True

# %%
library.name
# Out:
# 'Coolu Libraru'

# %%
library.books
# Out:
# [Book(title='The Silent Melody', author='Alice Wonderland', year=2018),
#  Book(title='Whispers of the Old Forest', author='Robert Green', year=1995),
#  Book(title='Stars Above Us', author='Clara Nova', year=2022),
#  Book(title='The Last Cartographer', author='Jonathan Swift', year=1987),
#  Book(title='Echoes in the Canyon', author='Sarah Fields', year=2001),
#  Book(title='Beyond the Horizon', author='Marcus Aurelius', year=1973),
#  Book(title='The Clockwork Heart', author='Victoria Steampunk', year=2010),
#  Book(title='Shadows of Yesterday', author='David Night', year=1965),
#  Book(title='The Golden Compass', author='Philip Pullman', year=1995),
#  Book(title='Aetherial Dreams', author='Evelyn Myst', year=2015)]

# %%
titles = [book.title for book in library.books]
titles
# Out:
# ['The Silent Melody',
#  'Whispers of the Old Forest',
#  'Stars Above Us',
#  'The Last Cartographer',
#  'Echoes in the Canyon',
#  'Beyond the Horizon',
#  'The Clockwork Heart',
#  'Shadows of Yesterday',
#  'The Golden Compass',
#  'Aetherial Dreams']

# %%
newer_books = [(book.title, book.year) for book in library.books if book.year > 1950]
newer_books
# Out:
# [('The Silent Melody', 2018),
#  ('Whispers of the Old Forest', 1995),
#  ('Stars Above Us', 2022),
#  ('The Last Cartographer', 1987),
#  ('Echoes in the Canyon', 2001),
#  ('Beyond the Horizon', 1973),
#  ('The Clockwork Heart', 2010),
#  ('Shadows of Yesterday', 1965),
#  ('The Golden Compass', 1995),
#  ('Aetherial Dreams', 2015)]

# %%
library.model_dump()
# Out:
# {'name': 'Coolu Libraru',
#  'books': [{'title': 'The Silent Melody',
#    'author': 'Alice Wonderland',
#    'year': 2018},
#   {'title': 'Whispers of the Old Forest',
#    'author': 'Robert Green',
#    'year': 1995},
#   {'title': 'Stars Above Us', 'author': 'Clara Nova', 'year': 2022},
#   {'title': 'The Last Cartographer', 'author': 'Jonathan Swift', 'year': 1987},
#   {'title': 'Echoes in the Canyon', 'author': 'Sarah Fields', 'year': 2001},
#   {'title': 'Beyond the Horizon', 'author': 'Marcus Aurelius', 'year': 1973},
#   {'title': 'The Clockwork Heart',
#    'author': 'Victoria Steampunk',
#    'year': 2010},
#   {'title': 'Shadows of Yesterday', 'author': 'David Night', 'year': 1965},
#   {'title': 'The Golden Compass', 'author': 'Philip Pullman', 'year': 1995},
#   {'title': 'Aetherial Dreams', 'author': 'Evelyn Myst', 'year': 2015}]}

# %%
with open("library.json", "w") as json_file:
    json_file.write(library.model_dump_json())

# %%
import pandas as pd

titles = [book.title for book in library.books]
years = [book.year for book in library.books]
authors = [book.author for book in library.books]

pd.DataFrame({"title": titles, "year": years, "author": authors})
# Out:
#                         title  year              author
# 0           The Silent Melody  2018    Alice Wonderland
# 1  Whispers of the Old Forest  1995        Robert Green
# 2              Stars Above Us  2022          Clara Nova
# 3       The Last Cartographer  1987      Jonathan Swift
# 4        Echoes in the Canyon  2001        Sarah Fields
# 5          Beyond the Horizon  1973     Marcus Aurelius
# 6         The Clockwork Heart  2010  Victoria Steampunk
# 7        Shadows of Yesterday  1965         David Night
# 8          The Golden Compass  1995      Philip Pullman
# 9            Aetherial Dreams  2015         Evelyn Myst
