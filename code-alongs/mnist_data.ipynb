# %% [markdown]
# Bildbehandling
# bild -> pixel -> siffror i matrisen -> nujmpy i python
# en pixel är en matris, RGB är tre olika matriser
# varje element i matrisen motsvarar pixelintensitet, positionen representerar positionen i bilden
#
# Färgbild, tredimensionell matris/ tensor(matriser i flera dimensioner)
#         [B] 0,5
#     [G] 0,1
# [R] 0,7
# - motsvarar en pixel, tex pixel 0 får denna färgen
# - size: [3x3x3]
#
# I numpy
# - np.array([[[]]]) - representerar tensorn
# med hjälp av slicing och manipulering kan man ändra färgen(sizen)
#
# import matplotlib.image as mping
# img = mping.("pic.png")
# plt.imshow(img)
