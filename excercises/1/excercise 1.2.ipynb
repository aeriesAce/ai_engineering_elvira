# %% [markdown]
# Perform EDA on the dataset and then predict the house prices using linear regression.
# - You can drop the categorical features and the date columns.
# - Then try ElasticNetCV and RidgeCV on the same dataset.
# - Record the scores in a dataframe with the columns mae, mse, rmse so you can compare the models.

# %%
import pandas as pd

df = pd.read_csv("../../data/data.csv")

df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df.drop(["date", "street", "city", "statezip", "country"], axis = 1, inplace = True)

# %%
df = pd.concat([df, pd.DataFrame(wine.target, columns = ["wine_class"])], axis = 1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = pd.concat([df, pd.DataFrame(wine.target, columns = ["wine_class"])], axis = 1)
#       2 df.head()
#
# NameError: name 'wine' is not defined
